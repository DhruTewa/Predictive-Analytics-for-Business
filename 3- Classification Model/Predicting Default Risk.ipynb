# %% [markdown]
# # Predicting Default Risk

# %% [markdown]
# ## The Business Problem
#
# You work for a small bank and are responsible for determining if customers are creditworthy to give a loan to. Your team typically gets 200 loan applications per week and approves them by hand.
#
# Due to a financial scandal that hit a competitive bank last week, you suddenly have an influx of new people applying for loans for your bank instead of the other bank in your city. All of a sudden you have nearly 500 loan applications to process this week!
#
# Your manager sees this new influx as a great opportunity and wants you to figure out how to process all of these loan applications within one week.
#
# You have the following information to work with:
#
# - Data on all past applications
# - The list of customers that need to be processed in the next few days

# %% [markdown]
# ## Explore and Cleanup the Data
#
# Following Steps were taken to clean up the data:
#
# - Are any of your numerical data fields highly-correlated with each other? The correlation should be at least .70 to be considered “high”.
# - Are there any missing data for each of the data fields? Fields with a lot of missing data should be removed
# - Are there only a few values in a subset of your data field? Does the data field look very uniform (there is only one value for the entire field?).
# - For the sake of consistency in the data cleanup process the data is imputed using the median of the entire data field.
#
# ### Variables in the dataset
#
# - Credit-Application-Result	*String*
# - Account-Balance	*String*
# - Duration-of-Credit-Month	*Double*
# - Payment-Status-of-Previous-Credit	*String*
# - Purpose	*String*
# - Credit-Amount	*Double*
# - Value-Savings-Stocks	*String*
# - Length-of-current-employment	*String*
# - Instalment-per-cent	*Double*
# - Guarantors	*String*
# - Duration-in-Current-address	*Double*
# - Most-valuable-available-asset	*Double*
# - Age-years	*Double*
# - Concurrent-Credits	*String*
# - Type-of-apartment	*Double*
# - No-of-Credits-at-this-Bank	*String*
# - Occupation	*Double*
# - No-of-dependents	*Double*
# - Telephone	*Double*
# - Foreign-Worker	*Double*

# %%
summary_wf=Image(filename="Summary_Workflow.PNG")
summary_wf

# %%
from IPython.display import display, Image, SVG, Math, YouTubeVideo
summary_image1=Image(filename="Field_Summary_1.PNG")
summary_image1

# %%
summary_image1=Image(filename="Field_Summary_2.PNG")
summary_image1

# %% [markdown]
# From the above analysis of variables, we found that:
#
# - Most of the variables has no missing values except `age` and `duration of current address`.
# - Missing Age values will be imputed by mean of the Age variable and duration of current address will not be considered in modeling
# - `Concurrent-Credits`, `Foreign-Worker` and `Guarantors` will not be consider in modeling because of it **low variability**
# - `Telephone` and `occupation` variable does not play any significance hence will not be consider

# %% [markdown]
# ### Correlation Table

# %%
corr_table=Image(filename="CorrelationTable.PNG")
corr_table

# %% [markdown]
# As none of the variable has high correaltion with each other hence all the variable will be selected in model generation.

# %% [markdown]
# ## Train your Classification Models
#
# You should choose 70% to create the Estimation set and 30% to create the Validation set.
#
# Train dataset using these models:
#
# - Logistic Regression
# - Decision Tree
# - Forest Model
# - Boosted Tree

# %%
WF_image1=Image(filename="Predict_Defalut_Risk_Workflow.PNG")
WF_image1

# %% [markdown]
# ### Logistic Regression Result

# %%
LR_image1=Image(filename="LR_Stepwise_Result.PNG")
LR_image1

# %%
LR_image2=Image(filename="LR_Stepwise_ModelComparision.PNG")
LR_image2

# %% [markdown]
# ### Decision Tree Result

# %%
DT_image1=Image(filename="DT1.PNG")
DT_image1

# %%
DT_image2=Image(filename="DT2.PNG")
DT_image2

# %%
DT_image3=Image(filename="DT3.PNG")
DT_image3

# %%
DT_image4=Image(filename="DT_ModelComparision.PNG")
DT_image4

# %% [markdown]
# ### Random Forest Results

# %%
RF_image1=Image(filename="RF1.PNG")
RF_image1

# %%
RF_image2=Image(filename="RF2.PNG")
RF_image2

# %%
RF_image3=Image(filename="RF3.PNG")
RF_image3

# %%
RF_image4=Image(filename="RF_ModelComparision.PNG")
RF_image4

# %% [markdown]
# ### Boosted Model Result

# %%
boosted_image1=Image(filename="Boosted1.PNG")
boosted_image1

# %%
boosted_image2=Image(filename="Boosted2.PNG")
boosted_image2

# %%
boosted_image3=Image(filename="Boosted_ModelComparision.PNG")
boosted_image3

# %% [markdown]
# ### All Model Comparision

# %%
All_image=Image(filename="All_ModelComparision.PNG")
All_image

# %%
ROC_image=Image(filename="All_ModelComparision_ROC.PNG")
ROC_image

# %% [markdown]
# ## Analysis
#
# Compare all of the models’ performance against each other. Decide on the best model and score your new customers. We decided `Random Forest Model ` has the best performance comparing to all other model.
#
# Hence, we used Random Forest to predict the scores of Creditworthiness of customers.

# %%
score_workflow=Image(filename="Score_Workflow.PNG")
score_workflow

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
score_data= pd.read_excel('Scores_Data.xlsx')
score_data[['Score_Creditworthy', 'Score_Non-Creditworthy']]
# Out:
#      Score_Creditworthy  Score_Non-Creditworthy
# 0                 0.914                   0.086
# 1                 0.756                   0.244
# 2                 0.640                   0.360
# 3                 0.882                   0.118
# 4                 0.806                   0.194
# 5                 0.868                   0.132
# 6                 0.642                   0.358
# 7                 0.814                   0.186
# 8                 0.274                   0.726
# 9                 0.672                   0.328
# 10                0.868                   0.132
# 11                0.824                   0.176
# 12                0.748                   0.252
# 13                0.562                   0.438
# 14                0.716                   0.284
# 15                0.908                   0.092
# 16                0.852                   0.148
# 17                0.896                   0.104
# 18                0.790                   0.210
# ...
